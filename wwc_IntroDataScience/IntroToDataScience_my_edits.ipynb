# %% [markdown]
# # Handling Dirty and Missing Data Using Pandas
#
# Presented by
#
# Saba Ali and Marissa Weiner
#
# Authors:
#
# Sian Lewis, Booz Allen Hamilton, sian.lewis@gmail.com
#
# Valeria Rozenbaum, Thomson Reuters

# %% [markdown]
# # ABOUT THE DATASET
#
# **The dataset we're working with today comes from the  [FlourishOA github repo](https://github.com/FlourishOA/Data)**
#
#
# **[FlourishOA](http://flourishoa.org/) was created by University of Washington's Information School Data Science and Analytics Lab to allow for the discovery of reputable open access publications .
# The data was compiled from a variety of sources, including researchers, web scraping, and the publishers themselves.**
#
# **Our dataset consists the following columns:**
#
# * **issn** international standardized code which identifies journals, magazines, and publications of both print and electronica media
# * **journal_name** name of the journal
# * **pub_name** name of the publisher
# * **is_hybrid**   definition unknown
# * **category**  subject classification of the journal
# * **url** web link to the publication

# %%
## First things first, let's import the packages we'll be using

import pandas as pd # Pandas library for data manipulation 
import numpy as np  # Numpy library for scientific computation 
import io           # for allowing pandas.read_csv to read in the file in google colab
import requests     # Allows requesting url

####################################### 
#######################################

url = 'https://raw.githubusercontent.com/brm2398/MLwomenwhocodedc/master/FlourishOA_DirtyMissing%20(1).csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#         issn                                       journal_name  \
# 0  0001-527X                           Acta Biochimica Polonica
# 1  0002-0397                                    Africa Spectrum
# 2  0003-0090  Bulletin of the American Museum of Natural His...
# 3  0003-5521                                    L'anthropologie
# 4  0004-1254  Arhiv Za Higijenu Rada I Toksikologiju-Archive...
#
#                       pub_name  is_hybrid                    category  url
# 0     ACTA BIOCHIMICA POLONICA          0  MOLECULAR AND CELL BIOLOGY  NaN
# 1                          NaN          0                         NaN  NaN
# 2  AMER MUSEUM NATURAL HISTORY          0       ECOLOGY AND EVOLUTION  NaN
# 3                     Elsevier          1                Anthropology  NaN
# 4                          NaN          0                         NaN  NaN

# %% [markdown]
# # Part 1: Cleaning Dirty Data
#
#  **Python References and Documentation**
# *  [Python Encodings](https://docs.python.org/3.7/library/codecs.html#encodings-and-unicode)
# *  [Pandas Read CSV](https://docs.python.org/2.4/lib/standard-encodings.html)
# * [Regular Expressions](https://docs.python.org/3.4/howto/regex.html)
# * [Regular Expressions with Pandas](https://www.dataquest.io/blog/regular-expressions-data-scientists/)

# %% [markdown]
# ## 1.a: Encoding

# %% [markdown]
# Character encodings allow your computer to interpret binary bytes (ex:111010101101) as real characters. This is done by mapping human readable characters to byte strings.
#
# While there are many encodings, UTF-8 is one of the most commonly used and is often the default for Python.
#
# Because of this, our encoding problems don't become problems until we have non UTF-8 data.
#
# **General Terms**
# - Decoding - To convert a string of bytes to a unicode string aka human readable.
# - Encoding - To represent a unicode string as a string of bytes.

# %%
# We don't have to specify the encoding when reading in a csv using pandas 
# and most of the time there aren't any issues because the data is likely utf8 encoded
# Spoiler alert: this data is not !

this_will_fail = pd.read_csv('https://raw.githubusercontent.com/FlourishOA/Data/master/api_journal11-13-17.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 17: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-54c971d99d23> in <module>
#       3 # Spoiler alert: this data is not !
#       4
# ----> 5 this_will_fail = pd.read_csv('https://raw.githubusercontent.com/FlourishOA/Data/master/api_journal11-13-17.csv')
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 17: invalid continuation byte

# %%
# Lets try reading in the actual csv file we uploaded at the top and specify decoding to utf8
s = requests.get(url).content
utf8_decode = pd.read_csv(io.StringIO(s.decode('utf-8')))
utf8_jn_list = utf8_decode['journal_name'].unique().tolist()


utf8_jn_list[:500]  # print out first 500 of the list we just made! (index 0 to 499)
# Out:
# ['Acta Biochimica Polonica',
#  'Africa Spectrum',
#  'Bulletin of the American Museum of Natural History',
#  "L'anthropologie",
#  'Arhiv Za Higijenu Rada I Toksikologiju-Archives of Industrial Hygiene and Toxicology',
#  'Arquivos De Neuro-Psiquiatria',
#  'Automatica',
#  'Brodogradnja',
#  'California Agriculture',
#  'Carbon',
#  'Cognition',
#  'College & Research Libraries',
#  'Contraception',
#  'Cortex',
#  'Croatica Chemica Acta',
#  'Cryobiology',
#  'Cryogenics',
#  'Disease-A-Month',
#  'Desalination',
#  'Chest',
#  'Erde',
#  'Finance a Uver-Czech Journal of Economics and Finance',
#  'Florida Entomologist',
#  'Fluoride',
#  'Fordham Law Review',
#  'Fuel',
#  'Futures',
#  'Gastroenterology',
#  'Geobios',
#  'Geoderma',
#  'Geofisica Internacional',
#  'Geoforum',
#  'George Washington Law Review',
#  'Georgetown Law Journal',
#  'Ginekologia Polska',
#  'Grasas Y Aceites',
#  'Harvard Journal on Legislation',
#  'Hastings Law Journal',
#  'Hereditas',
#  'Hiroshima Mathematical Journal',
#  'Icarus',
#  'Indian Journal of Cancer',
#  'Indian Journal of Communicable Diseases',
#  'Indian Journal of Dermatology',
#  'Indian Journal of Labour Economics',
#  'Indian Journal of Orthopaedics',
#  'Informes De La Construccion',
#  'Injury',
#  'Annali Dell Istituto Superiore Di Sanita',
#  'Jornal De Pediatria',
#  'Atherosclerosis',
#  'Journal of Genetics',
#  'Journal of Glaciology',
#  'Journal of Postgraduate Medicine',
#  'Kybernetika',
#  'Laeknabladid',
#  'Landtechnik',
#  'Buffalo Law Review',
#  'Leprosy Review',
#  'Lingua',
#  'Lithos',
#  'Maydica',
#  'Medical History',
#  'Medicina-Buenos Aires',
#  'Medicine',
#  'Metabolism',
#  'Journal of the Meteorological Society of Japan',
#  'Mljekarstvo',
#  'Journal of Nepal Medical Association',
#  'Neurochirurgie',
#  'Neurology India',
#  'Neuropharmacology',
#  'Neuropsychologia',
#  'Northwestern University Law Review',
#  'Nukleonika',
#  'Onderstepoort Journal of Veterinary Research',
#  'Orbis',
#  'Osaka Journal of Mathematics',
#  'Pathology',
#  'Physiotherapy',
#  'Phytochemistry',
#  'Phytopathologia Mediterranea',
#  'Polskie Archiwum Medycyny Wewnetrznej-Polish Archives of Internal Medicine',
#  'Polymer',
#  'Postepy Higieny I Medycyny Doswiadczalnej',
#  'Psychiatria Polska',
#  'Psychologica Belgica',
#  'Psychosomatics',
#  'Radiologia',
#  'Revista Brasileira De Anestesiologia',
#  'Revista Brasileira De Politica Internacional',
#  'RAE-Revista De Administracao De Empresas',
#  'Revista De Biologia Tropical',
#  'Revista De Metalurgia',
#  'Revista De Saude Publica',
#  'Revista Internacional De Sociologia',
#  'Revue De Geographie Alpine-Journal of Alpine Research',
#  'Rivista Italiana Di Paleontologia E Stratigrafia',
#  'Salud Publica De Mexico',
#  'Revista Do Instituto De Medicina Tropical De Sao Paulo',
#  'Silva Fennica',
#  'Singapore Medical Journal',
#  'Revista Da Sociedade Brasileira De Medicina Tropical',
#  'Soins',
#  'South African Journal of Science',
#  'Southern California Law Review',
#  'Steroids',
#  'Surgery',
#  'Talanta',
#  'Tectonophysics',
#  'Tetrahedron',
#  'Toxicon',
#  'Trimestre Economico',
#  'Ultrasonics',
#  'Vacuum',
#  'Virology',
#  'Journal of Hydrology and Hydromechanics',
#  'Vojnosanitetski Pregled',
#  'Bulletin of the World Health Organization',
#  'Washington Law Review',
#  'Wear',
#  'Wisconsin Law Review',
#  'Acta Amazonica',
#  'Acta Veterinaria Scandinavica',
#  'Aquaculture',
#  'Chemosphere',
#  'Ecology Law Quarterly',
#  'Inquiry-The Journal of Health Care Organization Provision and Financing',
#  'New Zealand Journal of Forestry Science',
#  'Psihologija',
#  'International Journal of Recent Surgical and Medical Sciences',
#  'Acta Neurobiologiae Experimentalis',
#  'Acta Protozoologica',
#  'Arquivos Brasileiros De Cardiologia',
#  'Baltica',
#  'Iheringia Serie Botanica',
#  'Iheringia Serie Zoologia',
#  'Memorias Do Instituto Oswaldo Cruz',
#  'Koedoe',
#  'Limnologica',
#  'Oceanologia',
#  'Revista Da Escola De Enfermagem Da USP',
#  'Trabajos De Prehistoria',
#  'Revista Brasileira De Entomologia',
#  'Fishery Bulletin',
#  'Urology',
#  'Environmental Health Perspectives',
#  'International Journal of Medical Research Professionals',
#  'Cell',
#  'Theriogenology',
#  'Revista Brasileira De Ciencia Do Solo',
#  'Pesquisa Agropecuaria Brasileira',
#  'Revista Brasileira De Fruticultura',
#  'Revista Caatinga',
#  'Quimica Nova',
#  'Revista Arvore',
#  'Engenharia Agricola',
#  'Pesquisa Veterinaria Brasileira',
#  'Planta Daninha',
#  'Genetics and Molecular Biology',
#  'Brazilian Journal of Medical and Biological Research',
#  'Food Science and Technology',
#  'Archives of Clinical Psychiatry',
#  'Horticultura Brasileira',
#  'Arquivo Brasileiro De Medicina Veterinaria E Zootecnia',
#  'Cadernos De Saude Publica',
#  'Acta Botanica Brasilica',
#  'Revista Brasileira De Cirurgia Cardiovascular',
#  'Acta Cirurgica Brasileira',
#  'Tempo Social',
#  'Acta Paulista De Enfermagem',
#  'Transinformacao',
#  'Journal of the Brazilian Chemical Society',
#  'Ciencia Rural',
#  'Brazilian Journal of Physics',
#  'Ciencia Florestal',
#  'Saude E Sociedade',
#  'Polimeros-Ciencia E Tecnologia',
#  'Revista Da Associacao Medica Brasileira',
#  'Brazilian Journal of Chemical Engineering',
#  'Cerne',
#  'Soldagem & Inspecao',
#  'Revista Latinoamericana De Psicologia',
#  'Biomedica',
#  'Ingenieria E Investigacion',
#  'Historia Critica',
#  'Revista MVZ Cordoba',
#  'Revista De Econom?a Del Rosario',
#  'Revista De Estudios Sociales',
#  'International Journal of High Speed Electronics and Systems?',
#  'Acta Ichthyologica Et Piscatoria',
#  'Animal Science Papers and Reports',
#  'Archives of Acoustics',
#  'Polish Polar Research',
#  'Agricultural Economics-Zemedelska Ekonomika',
#  'Displays',
#  'Biomaterials',
#  'Placenta',
#  'Neuropeptides',
#  'Bioscience Reports',
#  'Computer Communication Review',
#  'Plasmid',
#  'Clinical and Investigative Medicine',
#  'Intelligence',
#  'Endeavour',
#  'Ophthalmology',
#  'Neurotoxicology',
#  'Journal of Natural Products',
#  'Sigmod Record',
#  'BMGN-The Low Countries Historical Review',
#  'Studies in Mycology',
#  'Technovation',
#  'Geomorphology',
#  'Immunobiology',
#  'Revista Mexicana De Astronomia Y Astrofisica',
#  'Biointerface Research in Applied Chemistry',
#  'Investigacion Economica',
#  'Salud Mental',
#  'Ciencias Marinas',
#  'Investigacion Bibliotecologica',
#  'Atmosfera',
#  'Perfiles Latinoamericanos',
#  'Hidrobiologica',
#  'Rangelands',
#  'Appetite',
#  'Peptides',
#  'Chemical and Process Engineering-Inzynieria Chemiczna I Procesowa',
#  'Revista Espanola De Documentacion Cientifica',
#  'Lazaroa',
#  'Anales Del Jardin Botanico De Madrid',
#  'Psicologica',
#  'Fisioterapia',
#  'Nefrologia',
#  'Dynamis',
#  'Atencion Primaria',
#  'Magister',
#  'Anales De Psicologia',
#  'European Journal of Psychiatry',
#  'Gaceta Sanitaria',
#  'Psicothema',
#  'Raffles Bulletin of Zoology',
#  'Annals of Combinatorics',
#  'Knowledge and Information Systems',
#  'South African Journal of Animal Science',
#  'International Agrophysics',
#  'Bulletin of the Polish Academy of Sciences-Technical Sciences',
#  'Folia Histochemica Et Cytobiologica',
#  'Interbloc',
#  'Turkish Journal of Biochemistry-Turk Biyokimya Dergisi',
#  'Bulletin of Materials Science',
#  'Indian Journal of Pharmaceutical Sciences',
#  'Journal of Biosciences',
#  'Journal of Astrophysics and Astronomy',
#  'Eure-Revista Latinoamericana De Estudios Urbano Regionales',
#  'Austrian Journal of Earth Sciences',
#  'Journal of Earth System Science',
#  'Journal of Chemical Sciences',
#  'Proceedings of the Indian Academy of Sciences-Mathematical Sciences',
#  'Indian Journal of Pharmacology',
#  'Pakistan Veterinary Journal',
#  'Indian Journal of Medical Microbiology',
#  'South African Journal of Education',
#  'Sadhana-Academy Proceedings in Engineering Sciences',
#  'Annals of Saudi Medicine',
#  'Samj South African Medical Journal',
#  'Annals of Glaciology',
#  'Measurement',
#  'Cities',
#  'Vaccine',
#  'Midwifery',
#  'Mountain Research and Development',
#  'Polyhedron',
#  'Disease Markers',
#  'Pynchon Notes',
#  'Scandinavian Journal of Primary Health Care',
#  'Journal of International Medical Research',
#  'Toxicology',
#  'Biochimie',
#  'Resuscitation',
#  'Differentiation',
#  'Indian Journal of Ophthalmology',
#  'BioSystems',
#  'Acta Reumatologica Portuguesa',
#  'Hydrometallurgy',
#  'Ultramicroscopy',
#  'Poetics',
#  'Pramana-Journal of Physics',
#  'Annals Academy of Medicine Singapore',
#  'Omega',
#  'Nucleic Acids Research',
#  'Burns',
#  'Neuroscience',
#  'Psychoneuroendocrinology',
#  'Modeling Identification and Control',
#  'Catena',
#  'System',
#  'Medical Archives',
#  'Science of Sintering',
#  'Zdravstveno Varstvo',
#  'Chemical and Biochemical Engineering Quarterly',
#  'Promet-Traffic & Transportation',
#  'Acta Informatica Medica (Acta Inform Med)',
#  'Archives of Biological Sciences',
#  'Filomat',
#  'Thermal Science',
#  'Energy',
#  'Chemical Engineering Progress',
#  'Calphad',
#  'Acta Botanica Croatica',
#  'Anais Brasileiros De Dermatologia',
#  'Caldasia',
#  'Chinese Medical Journal',
#  'Estudios Geologicos-Madrid',
#  'Flora',
#  'Fitoterapia',
#  'Bulletin of the Geological Society of Finland',
#  'Hemijska Industrija',
#  'Irish Veterinary Journal',
#  'West Indian Medical Journal',
#  'Physics Letters B',
#  'Srpski Arhiv Za Celokupno Lekarstvo',
#  'Archives of Mechanics',
#  'Geothermics',
#  'Veterinarni Medicina',
#  'Indian Journal of Chemistry Section A-Inorganic Bio-Inorganic Physical Theoretic',
#  'Iete Journal of Research',
#  'Indian Journal of Pathology and Microbiology',
#  'Gene',
#  'Water Sa',
#  'Maturitas',
#  'Indian Journal of Dermatology Venereology & Leprology',
#  'South African Journal of Chemistry-Suid-Afrikaanse Tydskrif Vir Chemie',
#  'Canadian Studies in Population',
#  'Proceedings of the Japan Academy Series A-Mathematical Sciences',
#  'Proceedings of the Japan Academy Series B-Physical and Biological Sciences',
#  'Acta Medica Okayama',
#  'Haematologica',
#  'International Journal of Speleology',
#  'HYSTRIX-Italian Journal of Mammalogy',
#  'Endokrynologia Polska',
#  'Journal of Radiation Research',
#  'Materiales De Construccion',
#  'Medycyna Pracy',
#  'Revista Brasileira De Reumatologia',
#  'First Independent Scientific Journal',
#  'Veterinaria Italiana',
#  'Genetika-Belgrade',
#  'Nuclear Physics B',
#  'Pakistan Journal of Botany',
#  'Acta Palaeontologica Polonica',
#  'Revista Chilena De Historia Natural',
#  'Electronic Journal of Biotechnology',
#  'CLEI Electronic Journal',
#  'Cinta De Moebio: Revista De Epistemologia De Ciencias Sociales',
#  'EURE (Santiago) - Revista Latinoamericana De Estudios Urbano Regionales',
#  'Revista Musical Chilena',
#  'Biological Research',
#  'Teolog?a Y Vida',
#  'Medwave',
#  'Historia (Santiago)',
#  'Revista Chilena De Enfermedades Respiratorias',
#  'Boletin Latinoamericano Y Del Caribe De Plantas Medicinales Y Aromaticas',
#  'International Journal of Morphology',
#  'Journal of the Chilean Chemical Society',
#  'Dise?o Urbano Y Paisaje',
#  'Ius Et Praxis ',
#  'Revista Mad',
#  'Revista De Ciencia Pol?tica',
#  'Revista De Biologia Marina Y Oceanografia',
#  'Psykhe ',
#  'Magallania',
#  'Revista Chilena De Literatura',
#  'Revista Interamericana De Ambiente Y Turismo',
#  'Ingeniare :  Revista Chilena De Ingenier?A',
#  'Urbano',
#  'Revista De Filosof?A',
#  'Capic Review',
#  'Revista Perspectivas De La Comunicaci?n',
#  'Formaci?n Universitaria',
#  'Estudios Avanzados',
#  'Izquierdas',
#  'Latin American Journal of Aquatic Research',
#  'Onom?zein : Revista De Ling??stica, Filolog?a Y Traducci?n',
#  'Chilean Journal of Agricultural Research',
#  'Andean Geology',
#  'Ingenieria Industrial',
#  'Revista INVI',
#  'Biodiversity and Natural History',
#  'Byzantion Nea Hell?s',
#  'Avances en Ciencias E Ingenier?A',
#  'Revista De An?lisis Econ?mico (RAE)',
#  'Revista Estudios Hemisf?ricos Y Polares',
#  'Veritas : Revista De Filosof?a Y Teolog?a ',
#  'Bolet?n De Filolog?a ',
#  'Motricidad Humana',
#  'Revista Cl?nica De Periodoncia, Implantolog?a Y Rehabilitaci?n Oral',
#  'Imagonautas',
#  'Pensamiento Educativo: Revista De Investigaci?n Educacional Latinoamericana',
#  'Revista H?bitat Sustentable',
#  'Cisma: Revista De Humanidades Y Ciencias Sociales',
#  'Cuadernos De Historia',
#  'Comunicaci?n Y Medios',
#  'Revista Iberoamericana De Estudios Municipales',
#  'Revista De Gesti?n P?blica',
#  'Journal of Natural Resources and Development',
#  'Journal of Oral Research',
#  'Revista Chilena De Derecho Y Tecnolog?A',
#  'Cultura-Hombre-Sociedad',
#  'Communications in Inorganic Synthesis',
#  'Logos: Revista De Ling??stica, Literatura Y Filosof?A',
#  'Revista Eltopo',
#  'Revista De Estudios Pol?ticos Y Estrat?gicos',
#  'Estudios Internacionales',
#  'Journal of Pharmacy & Pharmacognosy Research',
#  'Fronteras: Revista De Ciencias Sociales Y Humanidades',
#  'Summa Psicologica UST',
#  'Revista Chilena De Fonoaudiolog?A',
#  'Revista Inclusiones',
#  'Revista De Historia Social Y De Las Mentalidades',
#  'Rivar',
#  'Revista Pedagog?a Universitaria Y Did?ctica Del Derecho',
#  'Ran',
#  'Arquitecturas Del Sur',
#  'TS Cuadernos De Trabajo Social',
#  'Texas Heart Institute Journal',
#  'Information Technology and Libraries',
#  'Indian Journal of Pharmaceutical and Biological Research',
#  'Alcohol',
#  'Family Medicine',
#  'Journal of Engineering Technology',
#  'Journal of Rehabilitation Research and Development',
#  'Global Journal of Multidisciplinary Studies',
#  'Archives of Public Health',
#  'Caribbean Journal of Science and Technology',
#  'WIMJ Open',
#  'Polar Research',
#  'Nordic Journal of Digital Literacy ',
#  'International Journal of Agriculture and Food Security',
#  'Informal Logic',
#  'Journal of Palliative Care',
#  'International Journal of English Research',
#  'Biology of Sport',
#  'Metrology and Measurement Systems',
#  'Ceramics-Silikaty',
#  'Horticultural Science',
#  'Folia Horticulturae',
#  'Ler Hist?ria',
#  'Analise Psicologica',
#  'Cultural Anthropology',
#  'Genomics',
#  'Computational Linguistics',
#  'Journal of Veterinary Internal Medicine',
#  'Journal of Applied Business Research',
#  'Journal of Real Estate Research',
#  'Neuron',
#  'Chinese Journal of Geophysics',
#  'Nutrition',
#  'Wildlife Biology',
#  'Journal of Physical Therapy Science',
#  'Journal of Epidemiology',
#  'Anthropological Science',
#  'Neurocomputing',
#  'Veterinary Research',
#  'Pathophysiology',
#  'Journal of the Formosan Medical Association',
#  'Meteorologische Zeitschrift',
#  'Mechanical Engineering Series',
#  'Acta Neurochirurgica',
#  'Zoology',
#  'Phytomedicine',
#  'Numerische Mathematik',
#  'Journal of Molecular Modeling',
#  'Journal of Universal Computer Science',
#  'European Journal of Medical Research',
#  'The Vldb Journal',
#  'Behavioural Neurology',
#  'Chemical Speciation and Bioavailability',
#  'Mechatronics',
#  'Mediators of Inflammation',
#  'Intermetallics',
#  'Micron',
#  'Structure',
#  'Asian Journal of Chemistry',
#  'Journal of Cytology',
#  'Biomedical Research',
#  'Indian Journal of Fibre & Textile Research',
#  'Indian Journal of Medical Research',
#  'Himalayan Geology',
#  'Current Pediatric Research',
#  'Annals of Indian Academy of Neurology',
#  'International Journal of Human Genetics',
#  'Conservation & Society',
#  'Indian Journal of Biotechnology',
#  'Journal of Digital Information Management',
#  'Antarctica Journal of Mathematics',
#  'Journal of Vector Borne Diseases',
#  'Journal of Minimal Access Surgery',
#  'International Journal of Tomography & Simulation',
#  'International Journal of Ecology & Development',
#  'Journal of Cell and Tissue Research']

# %% [markdown]
# **We are able to read the file in. Sometimes data will have the "?" character. If that is the case, we must do a different type of encoding.**
#
# ---
#
#
#
# **The ? signifies an unknown character and means that there is no utf8 mapping for that particular byte to be translated.**

# %%
# Let's try using a different encoding 
# Fun fact...kind of: latin1 / latin-1 / latin_1 is an alias for ISO-8859-1 
# So it's just like Kenisha said: if it doesn't work, try latin1, and that will work almost every time!

df = pd.read_csv('https://raw.githubusercontent.com/FlourishOA/Data/master/api_journal11-13-17.csv',encoding='latin1') 
jn_list = df['journal_name'].unique().tolist()
# the above code creates a Series --> call .unique() on a Series --> then convert it back to a list b/c it's a Series.


jn_list[:500]  # print out first 500 items in that list we just made
# Out:
# ['Acta Biochimica Polonica',
#  'Africa Spectrum',
#  'Bulletin of the American Museum of Natural History',
#  "L'anthropologie",
#  'Arhiv Za Higijenu Rada I Toksikologiju-Archives of Industrial Hygiene and Toxicology',
#  'Arquivos De Neuro-Psiquiatria',
#  'Automatica',
#  'Brodogradnja',
#  'California Agriculture',
#  'Carbon',
#  'Cognition',
#  'College & Research Libraries',
#  'Contraception',
#  'Cortex',
#  'Croatica Chemica Acta',
#  'Cryobiology',
#  'Cryogenics',
#  'Disease-A-Month',
#  'Desalination',
#  'Chest',
#  'Erde',
#  'Finance a Uver-Czech Journal of Economics and Finance',
#  'Florida Entomologist',
#  'Fluoride',
#  'Fordham Law Review',
#  'Fuel',
#  'Futures',
#  'Gastroenterology',
#  'Geobios',
#  'Geoderma',
#  'Geofisica Internacional',
#  'Geoforum',
#  'George Washington Law Review',
#  'Georgetown Law Journal',
#  'Ginekologia Polska',
#  'Grasas Y Aceites',
#  'Harvard Journal on Legislation',
#  'Hastings Law Journal',
#  'Hereditas',
#  'Hiroshima Mathematical Journal',
#  'Icarus',
#  'Indian Journal of Cancer',
#  'Indian Journal of Communicable Diseases',
#  'Indian Journal of Dermatology',
#  'Indian Journal of Labour Economics',
#  'Indian Journal of Orthopaedics',
#  'Informes De La Construccion',
#  'Injury',
#  'Annali Dell Istituto Superiore Di Sanita',
#  'Jornal De Pediatria',
#  'Atherosclerosis',
#  'Journal of Genetics',
#  'Journal of Glaciology',
#  'Journal of Postgraduate Medicine',
#  'Kybernetika',
#  'Laeknabladid',
#  'Landtechnik',
#  'Buffalo Law Review',
#  'Leprosy Review',
#  'Lingua',
#  'Lithos',
#  'Maydica',
#  'Medical History',
#  'Medicina-Buenos Aires',
#  'Medicine',
#  'Metabolism',
#  'Journal of the Meteorological Society of Japan',
#  'Mljekarstvo',
#  'Journal of Nepal Medical Association',
#  'Neurochirurgie',
#  'Neurology India',
#  'Neuropharmacology',
#  'Neuropsychologia',
#  'Northwestern University Law Review',
#  'Nukleonika',
#  'Onderstepoort Journal of Veterinary Research',
#  'Orbis',
#  'Osaka Journal of Mathematics',
#  'Pathology',
#  'Physiotherapy',
#  'Phytochemistry',
#  'Phytopathologia Mediterranea',
#  'Polskie Archiwum Medycyny Wewnetrznej-Polish Archives of Internal Medicine',
#  'Polymer',
#  'Postepy Higieny I Medycyny Doswiadczalnej',
#  'Psychiatria Polska',
#  'Psychologica Belgica',
#  'Psychosomatics',
#  'Radiologia',
#  'Revista Brasileira De Anestesiologia',
#  'Revista Brasileira De Politica Internacional',
#  'RAE-Revista De Administracao De Empresas',
#  'Revista De Biologia Tropical',
#  'Revista De Metalurgia',
#  'Revista De Saude Publica',
#  'Revista Internacional De Sociologia',
#  'Revue De Geographie Alpine-Journal of Alpine Research',
#  'Rivista Italiana Di Paleontologia E Stratigrafia',
#  'Salud Publica De Mexico',
#  'Revista Do Instituto De Medicina Tropical De Sao Paulo',
#  'Silva Fennica',
#  'Singapore Medical Journal',
#  'Revista Da Sociedade Brasileira De Medicina Tropical',
#  'Soins',
#  'South African Journal of Science',
#  'Southern California Law Review',
#  'Steroids',
#  'Surgery',
#  'Talanta',
#  'Tectonophysics',
#  'Tetrahedron',
#  'Toxicon',
#  'Trimestre Economico',
#  'Ultrasonics',
#  'Vacuum',
#  'Virology',
#  'Journal of Hydrology and Hydromechanics',
#  'Vojnosanitetski Pregled',
#  'Bulletin of the World Health Organization',
#  'Washington Law Review',
#  'Wear',
#  'Wisconsin Law Review',
#  'Acta Amazonica',
#  'Acta Veterinaria Scandinavica',
#  'Aquaculture',
#  'Chemosphere',
#  'Ecology Law Quarterly',
#  'Inquiry-The Journal of Health Care Organization Provision and Financing',
#  'New Zealand Journal of Forestry Science',
#  'Psihologija',
#  'International Journal of Recent Surgical and Medical Sciences',
#  'Acta Neurobiologiae Experimentalis',
#  'Acta Protozoologica',
#  'Arquivos Brasileiros De Cardiologia',
#  'Baltica',
#  'Iheringia Serie Botanica',
#  'Iheringia Serie Zoologia',
#  'Memorias Do Instituto Oswaldo Cruz',
#  'Koedoe',
#  'Limnologica',
#  'Oceanologia',
#  'Revista Da Escola De Enfermagem Da USP',
#  'Trabajos De Prehistoria',
#  'Revista Brasileira De Entomologia',
#  'Fishery Bulletin',
#  'Urology',
#  'Environmental Health Perspectives',
#  'International Journal of Medical Research Professionals',
#  'Cell',
#  'Theriogenology',
#  'Revista Brasileira De Ciencia Do Solo',
#  'Pesquisa Agropecuaria Brasileira',
#  'Revista Brasileira De Fruticultura',
#  'Revista Caatinga',
#  'Quimica Nova',
#  'Revista Arvore',
#  'Engenharia Agricola',
#  'Pesquisa Veterinaria Brasileira',
#  'Planta Daninha',
#  'Genetics and Molecular Biology',
#  'Brazilian Journal of Medical and Biological Research',
#  'Food Science and Technology',
#  'Archives of Clinical Psychiatry',
#  'Horticultura Brasileira',
#  'Arquivo Brasileiro De Medicina Veterinaria E Zootecnia',
#  'Cadernos De Saude Publica',
#  'Acta Botanica Brasilica',
#  'Revista Brasileira De Cirurgia Cardiovascular',
#  'Acta Cirurgica Brasileira',
#  'Tempo Social',
#  'Acta Paulista De Enfermagem',
#  'Transinformacao',
#  'Journal of the Brazilian Chemical Society',
#  'Ciencia Rural',
#  'Brazilian Journal of Physics',
#  'Ciencia Florestal',
#  'Saude E Sociedade',
#  'Polimeros-Ciencia E Tecnologia',
#  'Revista Da Associacao Medica Brasileira',
#  'Brazilian Journal of Chemical Engineering',
#  'Cerne',
#  'Soldagem & Inspecao',
#  'Revista Latinoamericana De Psicologia',
#  'Biomedica',
#  'Ingenieria E Investigacion',
#  'Historia Critica',
#  'Revista MVZ Cordoba',
#  'Revista De Economía Del Rosario',
#  'Revista De Estudios Sociales',
#  'International Journal of High Speed Electronics and Systems\xa0',
#  'Acta Ichthyologica Et Piscatoria',
#  'Animal Science Papers and Reports',
#  'Archives of Acoustics',
#  'Polish Polar Research',
#  'Agricultural Economics-Zemedelska Ekonomika',
#  'Displays',
#  'Biomaterials',
#  'Placenta',
#  'Neuropeptides',
#  'Bioscience Reports',
#  'Computer Communication Review',
#  'Plasmid',
#  'Clinical and Investigative Medicine',
#  'Intelligence',
#  'Endeavour',
#  'Ophthalmology',
#  'Neurotoxicology',
#  'Journal of Natural Products',
#  'Sigmod Record',
#  'BMGN-The Low Countries Historical Review',
#  'Studies in Mycology',
#  'Technovation',
#  'Geomorphology',
#  'Immunobiology',
#  'Revista Mexicana De Astronomia Y Astrofisica',
#  'Biointerface Research in Applied Chemistry',
#  'Investigacion Economica',
#  'Salud Mental',
#  'Ciencias Marinas',
#  'Investigacion Bibliotecologica',
#  'Atmosfera',
#  'Perfiles Latinoamericanos',
#  'Hidrobiologica',
#  'Rangelands',
#  'Appetite',
#  'Peptides',
#  'Chemical and Process Engineering-Inzynieria Chemiczna I Procesowa',
#  'Revista Espanola De Documentacion Cientifica',
#  'Lazaroa',
#  'Anales Del Jardin Botanico De Madrid',
#  'Psicologica',
#  'Fisioterapia',
#  'Nefrologia',
#  'Dynamis',
#  'Atencion Primaria',
#  'Magister',
#  'Anales De Psicologia',
#  'European Journal of Psychiatry',
#  'Gaceta Sanitaria',
#  'Psicothema',
#  'Raffles Bulletin of Zoology',
#  'Annals of Combinatorics',
#  'Knowledge and Information Systems',
#  'South African Journal of Animal Science',
#  'International Agrophysics',
#  'Bulletin of the Polish Academy of Sciences-Technical Sciences',
#  'Folia Histochemica Et Cytobiologica',
#  'Interbloc',
#  'Turkish Journal of Biochemistry-Turk Biyokimya Dergisi',
#  'Bulletin of Materials Science',
#  'Indian Journal of Pharmaceutical Sciences',
#  'Journal of Biosciences',
#  'Journal of Astrophysics and Astronomy',
#  'Eure-Revista Latinoamericana De Estudios Urbano Regionales',
#  'Austrian Journal of Earth Sciences',
#  'Journal of Earth System Science',
#  'Journal of Chemical Sciences',
#  'Proceedings of the Indian Academy of Sciences-Mathematical Sciences',
#  'Indian Journal of Pharmacology',
#  'Pakistan Veterinary Journal',
#  'Indian Journal of Medical Microbiology',
#  'South African Journal of Education',
#  'Sadhana-Academy Proceedings in Engineering Sciences',
#  'Annals of Saudi Medicine',
#  'Samj South African Medical Journal',
#  'Annals of Glaciology',
#  'Measurement',
#  'Cities',
#  'Vaccine',
#  'Midwifery',
#  'Mountain Research and Development',
#  'Polyhedron',
#  'Disease Markers',
#  'Pynchon Notes',
#  'Scandinavian Journal of Primary Health Care',
#  'Journal of International Medical Research',
#  'Toxicology',
#  'Biochimie',
#  'Resuscitation',
#  'Differentiation',
#  'Indian Journal of Ophthalmology',
#  'BioSystems',
#  'Acta Reumatologica Portuguesa',
#  'Hydrometallurgy',
#  'Ultramicroscopy',
#  'Poetics',
#  'Pramana-Journal of Physics',
#  'Annals Academy of Medicine Singapore',
#  'Omega',
#  'Nucleic Acids Research',
#  'Burns',
#  'Neuroscience',
#  'Psychoneuroendocrinology',
#  'Modeling Identification and Control',
#  'Catena',
#  'System',
#  'Medical Archives',
#  'Science of Sintering',
#  'Zdravstveno Varstvo',
#  'Chemical and Biochemical Engineering Quarterly',
#  'Promet-Traffic & Transportation',
#  'Acta Informatica Medica (Acta Inform Med)',
#  'Archives of Biological Sciences',
#  'Filomat',
#  'Thermal Science',
#  'Energy',
#  'Chemical Engineering Progress',
#  'Calphad',
#  'Acta Botanica Croatica',
#  'Anais Brasileiros De Dermatologia',
#  'Caldasia',
#  'Chinese Medical Journal',
#  'Estudios Geologicos-Madrid',
#  'Flora',
#  'Fitoterapia',
#  'Bulletin of the Geological Society of Finland',
#  'Hemijska Industrija',
#  'Irish Veterinary Journal',
#  'West Indian Medical Journal',
#  'Physics Letters B',
#  'Srpski Arhiv Za Celokupno Lekarstvo',
#  'Archives of Mechanics',
#  'Geothermics',
#  'Veterinarni Medicina',
#  'Indian Journal of Chemistry Section A-Inorganic Bio-Inorganic Physical Theoretic',
#  'Iete Journal of Research',
#  'Indian Journal of Pathology and Microbiology',
#  'Gene',
#  'Water Sa',
#  'Maturitas',
#  'Indian Journal of Dermatology Venereology & Leprology',
#  'South African Journal of Chemistry-Suid-Afrikaanse Tydskrif Vir Chemie',
#  'Canadian Studies in Population',
#  'Proceedings of the Japan Academy Series A-Mathematical Sciences',
#  'Proceedings of the Japan Academy Series B-Physical and Biological Sciences',
#  'Acta Medica Okayama',
#  'Haematologica',
#  'International Journal of Speleology',
#  'HYSTRIX-Italian Journal of Mammalogy',
#  'Endokrynologia Polska',
#  'Journal of Radiation Research',
#  'Materiales De Construccion',
#  'Medycyna Pracy',
#  'Revista Brasileira De Reumatologia',
#  'First Independent Scientific Journal',
#  'Veterinaria Italiana',
#  'Genetika-Belgrade',
#  'Nuclear Physics B',
#  'Pakistan Journal of Botany',
#  'Acta Palaeontologica Polonica',
#  'Revista Chilena De Historia Natural',
#  'Electronic Journal of Biotechnology',
#  'CLEI Electronic Journal',
#  'Cinta De Moebio: Revista De Epistemologia De Ciencias Sociales',
#  'EURE (Santiago) - Revista Latinoamericana De Estudios Urbano Regionales',
#  'Revista Musical Chilena',
#  'Biological Research',
#  'Teología Y Vida',
#  'Medwave',
#  'Historia (Santiago)',
#  'Revista Chilena De Enfermedades Respiratorias',
#  'Boletin Latinoamericano Y Del Caribe De Plantas Medicinales Y Aromaticas',
#  'International Journal of Morphology',
#  'Journal of the Chilean Chemical Society',
#  'Diseño Urbano Y Paisaje',
#  'Ius Et Praxis ',
#  'Revista Mad',
#  'Revista De Ciencia Política',
#  'Revista De Biologia Marina Y Oceanografia',
#  'Psykhe ',
#  'Magallania',
#  'Revista Chilena De Literatura',
#  'Revista Interamericana De Ambiente Y Turismo',
#  'Ingeniare :  Revista Chilena De IngenieríA',
#  'Urbano',
#  'Revista De FilosofíA',
#  'Capic Review',
#  'Revista Perspectivas De La Comunicación',
#  'Formación Universitaria',
#  'Estudios Avanzados',
#  'Izquierdas',
#  'Latin American Journal of Aquatic Research',
#  'Onomázein : Revista De Lingüística, Filología Y Traducción',
#  'Chilean Journal of Agricultural Research',
#  'Andean Geology',
#  'Ingenieria Industrial',
#  'Revista INVI',
#  'Biodiversity and Natural History',
#  'Byzantion Nea Hellás',
#  'Avances en Ciencias E IngenieríA',
#  'Revista De Análisis Económico (RAE)',
#  'Revista Estudios Hemisféricos Y Polares',
#  'Veritas : Revista De Filosofía Y Teología ',
#  'Boletín De Filología ',
#  'Motricidad Humana',
#  'Revista Clínica De Periodoncia, Implantología Y Rehabilitación Oral',
#  'Imagonautas',
#  'Pensamiento Educativo: Revista De Investigación Educacional Latinoamericana',
#  'Revista Hábitat Sustentable',
#  'Cisma: Revista De Humanidades Y Ciencias Sociales',
#  'Cuadernos De Historia',
#  'Comunicación Y Medios',
#  'Revista Iberoamericana De Estudios Municipales',
#  'Revista De Gestión Pública',
#  'Journal of Natural Resources and Development',
#  'Journal of Oral Research',
#  'Revista Chilena De Derecho Y TecnologíA',
#  'Cultura-Hombre-Sociedad',
#  'Communications in Inorganic Synthesis',
#  'Logos: Revista De Lingüística, Literatura Y FilosofíA',
#  'Revista Eltopo',
#  'Revista De Estudios Políticos Y Estratégicos',
#  'Estudios Internacionales',
#  'Journal of Pharmacy & Pharmacognosy Research',
#  'Fronteras: Revista De Ciencias Sociales Y Humanidades',
#  'Summa Psicologica UST',
#  'Revista Chilena De FonoaudiologíA',
#  'Revista Inclusiones',
#  'Revista De Historia Social Y De Las Mentalidades',
#  'Rivar',
#  'Revista Pedagogía Universitaria Y Didáctica Del Derecho',
#  'Ran',
#  'Arquitecturas Del Sur',
#  'TS Cuadernos De Trabajo Social',
#  'Texas Heart Institute Journal',
#  'Information Technology and Libraries',
#  'Indian Journal of Pharmaceutical and Biological Research',
#  'Alcohol',
#  'Family Medicine',
#  'Journal of Engineering Technology',
#  'Journal of Rehabilitation Research and Development',
#  'Global Journal of Multidisciplinary Studies',
#  'Archives of Public Health',
#  'Caribbean Journal of Science and Technology',
#  'WIMJ Open',
#  'Polar Research',
#  'Nordic Journal of Digital Literacy ',
#  'International Journal of Agriculture and Food Security',
#  'Informal Logic',
#  'Journal of Palliative Care',
#  'International Journal of English Research',
#  'Biology of Sport',
#  'Metrology and Measurement Systems',
#  'Ceramics-Silikaty',
#  'Horticultural Science',
#  'Folia Horticulturae',
#  'Ler História',
#  'Analise Psicologica',
#  'Cultural Anthropology',
#  'Genomics',
#  'Computational Linguistics',
#  'Journal of Veterinary Internal Medicine',
#  'Journal of Applied Business Research',
#  'Journal of Real Estate Research',
#  'Neuron',
#  'Chinese Journal of Geophysics',
#  'Nutrition',
#  'Wildlife Biology',
#  'Journal of Physical Therapy Science',
#  'Journal of Epidemiology',
#  'Anthropological Science',
#  'Neurocomputing',
#  'Veterinary Research',
#  'Pathophysiology',
#  'Journal of the Formosan Medical Association',
#  'Meteorologische Zeitschrift',
#  'Mechanical Engineering Series',
#  'Acta Neurochirurgica',
#  'Zoology',
#  'Phytomedicine',
#  'Numerische Mathematik',
#  'Journal of Molecular Modeling',
#  'Journal of Universal Computer Science',
#  'European Journal of Medical Research',
#  'The Vldb Journal',
#  'Behavioural Neurology',
#  'Chemical Speciation and Bioavailability',
#  'Mechatronics',
#  'Mediators of Inflammation',
#  'Intermetallics',
#  'Micron',
#  'Structure',
#  'Asian Journal of Chemistry',
#  'Journal of Cytology',
#  'Biomedical Research',
#  'Indian Journal of Fibre & Textile Research',
#  'Indian Journal of Medical Research',
#  'Himalayan Geology',
#  'Current Pediatric Research',
#  'Annals of Indian Academy of Neurology',
#  'International Journal of Human Genetics',
#  'Conservation & Society',
#  'Indian Journal of Biotechnology',
#  'Journal of Digital Information Management',
#  'Antarctica Journal of Mathematics',
#  'Journal of Vector Borne Diseases',
#  'Journal of Minimal Access Surgery',
#  'International Journal of Tomography & Simulation',
#  'International Journal of Ecology & Development',
#  'Journal of Cell and Tissue Research']

# %% [markdown]
# #### With the correct encoding, we can read the text from our previous example and see what the unknown characters were
#
#
#
# *   utf8:
#
# Onom?zein : Revista De Ling??stica, Filolog?a Y Traducci?nOnomázein
# *   ISO-8859-1:
#
# Onomázein : Revista De Lingüística, Filología Y Traducción

# %%
df.columns   # shows all the items (columns) (features) in the dataframe
# Out:
# Index(['issn', 'journal_name', 'pub_name', 'is_hybrid', 'category', 'url'], dtype='object')

# %%
df['issn']   # gives you that Series
# Out:
# 0        0001-527X
# 1        0002-0397
# 2        0003-0090
# 3        0003-5521
# 4        0004-1254
# 5        0004-282X
# 6        0005-1098
# 7        0007-215X
# 8        0008-0845
# 9        0008-6223
# 10       0010-0277
# 11       0010-0870
# 12       0010-7824
# 13       0010-9452
# 14       0011-1643
# 15       0011-2240
# 16       0011-2275
# 17       0011-5029
# 18       0011-9164
# 19       0012-3692
# 20       0013-9998
# 21       0015-1920
# 22       0015-4040
# 23       0015-4725
# 24       0015-704X
# 25       0016-2361
# 26       0016-3287
# 27       0016-5085
# 28       0016-6995
# 29       0016-7061
#            ...
# 13119    7801-2016
# 13120    7853-1101
# 13121    7853-1292
# 13122    7853-2108
# 13123    7901-2015
# 13124    7937-2015
# 13125    8106-1346
# 13126    8140-2016
# 13127    8165-2015
# 13128    8244-8750
# 13129    8247-2016
# 13130    8345-2016
# 13131    8455-2015
# 13132    8487-6366
# 13133    8555-2016
# 13134    8619-2016
# 13135    8756-3282
# 13136    9001-2008
# 13137    9046-2014
# 13138    9134-2016
# 13139    9138-2015
# 13140    9341-2016
# 13141    9377-2016
# 13142    9521-4569
# 13143    9521-5978
# 13144    9680-5667
# 13145    9681-2016
# 13146    9714-1800
# 13147    9826-4263
# 13148    9933-2016
# Name: issn, Length: 13149, dtype: object

# %%
df[['issn','journal_name']]  # you can do two at a time! but use double-brackets
# Out:
#             issn                                       journal_name
# 0      0001-527X                           Acta Biochimica Polonica
# 1      0002-0397                                    Africa Spectrum
# 2      0003-0090  Bulletin of the American Museum of Natural His...
# 3      0003-5521                                    L'anthropologie
# 4      0004-1254  Arhiv Za Higijenu Rada I Toksikologiju-Archive...
# 5      0004-282X                      Arquivos De Neuro-Psiquiatria
# 6      0005-1098                                         Automatica
# 7      0007-215X                                       Brodogradnja
# 8      0008-0845                             California Agriculture
# 9      0008-6223                                             Carbon
# 10     0010-0277                                          Cognition
# 11     0010-0870                       College & Research Libraries
# 12     0010-7824                                      Contraception
# 13     0010-9452                                             Cortex
# 14     0011-1643                              Croatica Chemica Acta
# 15     0011-2240                                        Cryobiology
# 16     0011-2275                                         Cryogenics
# 17     0011-5029                                    Disease-A-Month
# 18     0011-9164                                       Desalination
# 19     0012-3692                                              Chest
# 20     0013-9998                                               Erde
# 21     0015-1920  Finance a Uver-Czech Journal of Economics and ...
# 22     0015-4040                               Florida Entomologist
# 23     0015-4725                                           Fluoride
# 24     0015-704X                                 Fordham Law Review
# 25     0016-2361                                               Fuel
# 26     0016-3287                                            Futures
# 27     0016-5085                                   Gastroenterology
# 28     0016-6995                                            Geobios
# 29     0016-7061                                           Geoderma
# ...          ...                                                ...
# 13119  7801-2016  International Journal of Engineering Sciences ...
# 13120  7853-1101     International Journal of AIDS and HIV Research
# 13121  7853-1292             Advanced Journal of Surgical Pathology
# 13122  7853-2108  International Journal of Pregnancy and Childbirth
# 13123  7901-2015      International Journal of Development Research
# 13124  7937-2015  International Journal of Advance Research and ...
# 13125  8106-1346  The International Journal of Business & Manage...
# 13126  8140-2016  International Journal of Innovative and Applie...
# 13127  8165-2015  International Journal of Innovations in Engine...
# 13128  8244-8750  International Journal of Computer Engineering ...
# 13129  8247-2016  International Journal of Emerging Research in ...
# 13130  8345-2016  International Journal of Engineering and Compu...
# 13131  8455-2015         International Journal of Indian Psychology
# 13132  8487-6366  Canadian International Journal of Science and ...
# 13133  8555-2016  American Journal of Innovative Research and Ap...
# 13134  8619-2016  International Journal of Advanced Networking a...
# 13135  8756-3282                                               Bone
# 13136  9001-2008  International Journal of Engineering Technolog...
# 13137  9046-2014          International Journal of Current Research
# 13138  9134-2016  International Journal of Computer Engineering ...
# 13139  9138-2015  International Journal of Engineering Sciences ...
# 13140  9341-2016  International Journal of New Technology and Re...
# 13141  9377-2016  International Journal of Current Advanced Rese...
# 13142  9521-4569  International Journal of Fishery Science and A...
# 13143  9521-5978  International Journal of Dental and Health Sci...
# 13144  9680-5667  International Journal of Innovative Computer S...
# 13145  9681-2016  International Journal for Research in Applied ...
# 13146  9714-1800                                     Bioinformation
# 13147  9826-4263               Advances in Biomedicine and Pharmacy
# 13148  9933-2016  International Journal for Development of Compu...
#
# [13149 rows x 2 columns]

# %%
df.loc[:,'issn']       # all rows, column='issn'
df.loc[0:10, 'issn']   # rows 0-10, column='issn'
# Out:
# 0     0001-527X
# 1     0002-0397
# 2     0003-0090
# 3     0003-5521
# 4     0004-1254
# 5     0004-282X
# 6     0005-1098
# 7     0007-215X
# 8     0008-0845
# 9     0008-6223
# 10    0010-0277
# Name: issn, dtype: object

# %%
df.iloc[0,0]  # first row, first column
df.iloc[:,0]  # all rows, first column
# Out:
# 0        0001-527X
# 1        0002-0397
# 2        0003-0090
# 3        0003-5521
# 4        0004-1254
# 5        0004-282X
# 6        0005-1098
# 7        0007-215X
# 8        0008-0845
# 9        0008-6223
# 10       0010-0277
# 11       0010-0870
# 12       0010-7824
# 13       0010-9452
# 14       0011-1643
# 15       0011-2240
# 16       0011-2275
# 17       0011-5029
# 18       0011-9164
# 19       0012-3692
# 20       0013-9998
# 21       0015-1920
# 22       0015-4040
# 23       0015-4725
# 24       0015-704X
# 25       0016-2361
# 26       0016-3287
# 27       0016-5085
# 28       0016-6995
# 29       0016-7061
#            ...
# 13119    7801-2016
# 13120    7853-1101
# 13121    7853-1292
# 13122    7853-2108
# 13123    7901-2015
# 13124    7937-2015
# 13125    8106-1346
# 13126    8140-2016
# 13127    8165-2015
# 13128    8244-8750
# 13129    8247-2016
# 13130    8345-2016
# 13131    8455-2015
# 13132    8487-6366
# 13133    8555-2016
# 13134    8619-2016
# 13135    8756-3282
# 13136    9001-2008
# 13137    9046-2014
# 13138    9134-2016
# 13139    9138-2015
# 13140    9341-2016
# 13141    9377-2016
# 13142    9521-4569
# 13143    9521-5978
# 13144    9680-5667
# 13145    9681-2016
# 13146    9714-1800
# 13147    9826-4263
# 13148    9933-2016
# Name: issn, Length: 13149, dtype: object

# %% [markdown]
# ### iloc versus loc
# Suppose you are doing data analysis on multiple data sources...
#
# But the columns are slightly differently aligned!
#
# If you call by position (iloc) you may get the wrong one...
#
# But if you call by name (loc) then you get the right ones...

# %%
## Let's do a quick profile of our dataset 

def eda(dataframe):
    print('MISSING VALUES\n', dataframe.isnull().sum())   # find all null values. sum them.
    print('\n DATA TYPES \n', dataframe.dtypes)           # what are all the data types?
    print('\n DATA SHAPE \n', dataframe.shape)            # what are the dimensions of the df?
    print('\n DATA DESCRIBE \n', dataframe.describe())    # 'describe' does statistical stuff on all_num columns

    # for 'item' in dataframe one of the words in dataframe.columns
    for item in dataframe:                                # for item in dataframe = for feature/column in dataframe
        print('\n UNIQUE VALUE TOTALS \n',item)           # first print info
        print(dataframe[item].nunique())                  # then look up how many unique items per feature/column
        print(dataframe[item].value_counts())             # this is A LOT to display, but pretty awesome info!
        
eda(df)
# Out:
# MISSING VALUES
#  issn               0
# journal_name       0
# pub_name        1470
# is_hybrid          0
# category        6331
# url             6788
# dtype: int64
#
#  DATA TYPES
#  issn            object
# journal_name    object
# pub_name        object
# is_hybrid        int64
# category        object
# url             object
# dtype: object
#
#  DATA SHAPE
#  (13149, 6)
#
#  DATA DESCRIBE
#            is_hybrid
# count  13149.000000
# mean       0.131949
# std        0.338448
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
#  UNIQUE VALUE TOTALS
#  issn
# 13149
# 1993-601X    1
# 1934-1482    1
# 1063-7834    1
# 2326-7488    1
# 2469-9888    1
# 1816-353X    1
# 0190-0528    1
# 2254-7088    1
# 1936-606X    1
# 1679-849X    1
# 2345-4997    1
# 2374-5436    1
# 2381-5639    1
# 2254-7673    1
# 2058-8615    1
# 2146-3298    1
# 1822-7805    1
# 1961-9510    1
# 1438-5627    1
# 2247-806X    1
# 1435-604X    1
# 2338-1353    1
# 1812-5735    1
# 1989-7790    1
# 2469-5858    1
# 2047-0398    1
# 2175-9405    1
# 1994-5442    1
# 2049-9256    1
# 1937-8602    1
#             ..
# 2179-9164    1
# 0304-422X    1
# 2230-9936    1
# 2476-9223    1
# 2336-2766    1
# 2374-8257    1
# 1880-5779    1
# 2327-5340    1
# 1432-1270    1
# 2451-3105    1
# 1573-4803    1
# 2502-7778    1
# 2226-7875    1
# 1989-3922    1
# 1573-7012    1
# 1528-3658    1
# 2314-4599    1
# 2090-4681    1
# 1573-4919    1
# 2090-195X    1
# 1868-6966    1
# 2141-2596    1
# 1800-7473    1
# 1179-299X    1
# 1983-2125    1
# 1471-2121    1
# 2386-8295    1
# 2202-5677    1
# 1478-6354    1
# 1550-1477    1
# Name: issn, Length: 13149, dtype: int64
#
#  UNIQUE VALUE TOTALS
#  journal_name
# 11581
# International Journal of Humanities and Cultural Studies                          68
# Experiment                                                                        62
# International Journal of Multidisciplinary Education and Research                 52
# International Journal of Medical Science and Public Health                        45
# International Journal of Informative and Futuristic Research                      36
# International Journal of Pediatrics                                               32
# International Journal of Renewable Energy Research                                22
# International Journal of Recent Surgical and Medical Sciences                     13
# Indian Journal of Natural Sciences                                                12
# International Journal of Application or Innovation in Engineering & Management     9
# International Journal of Recent Scientific Research                                8
# International Journal of Computer Engineering in Research Trends                   8
# Biointerface Research in Applied Chemistry                                         7
# Canadian Chemical Transactions                                                     7
# International Journal of Computer Applications                                     6
# Genetics and Molecular Research                                                    5
# Advances in Biomedicine and Pharmacy                                               5
# International Educational E-Journal                                                4
# International Journal of Pharma Professional<U+0092>s Research                     4
# English Language Teaching                                                          4
# International Journal of Computer Science and Information Technology               4
# International Journal of Engineering and Applied Sciences                          4
# International Journal of Advance Research and Innovative Ideas in Education        4
# Canadian International Journal of Science and Technology                           4
# Journal of Artificial Intelligence                                                 4
# International Journal of Network Security                                          4
# International Journal of Research GRANTHAALAYAH                                    4
# International Journal of Advanced Engineering Research and Science                 4
# International Journal of Environment                                               4
# International Journal of Environmental & Agriculture Research                      4
#                                                                                   ..
# Revista Digital De Investigación en Docencia Universitaria                         1
# REMHU: Revista Interdisciplinar Da Mobilidade Humana                               1
# International Journal of Advances in Applied Mathematics and Mechanics             1
# Sino-Us English Teaching                                                           1
# International Journal of Life Science and Pharma Research                          1
# Mathematics Education Research Journal                                             1
# Mitologías Hoy                                                                     1
# ISRN Immunology                                                                    1
# International Journal of Hospitality and Tourism                                   1
# Revista De Administração De Roraima                                                1
# InVet                                                                              1
# Exchanges: The Warwick Research Journal                                            1
# Jangwa Pana                                                                        1
# Heilberufescience                                                                  1
# Voprosy Regulirovaniâ Èkonomiki                                                    1
# Advances in Multimedia                                                             1
# Social Inclusion                                                                   1
# Revista Historia De La Educación Latinoamericana                                   1
# Journal of Cutaneous and Aesthetic Surgery                                         1
# Acción Psicológica                                                                 1
# International Journal of Game Theory                                               1
# Revista Políticas Públicas & Cidades                                               1
# International Journal of Applied Research in Natural Products                      1
# Journal of the Arkansas Academy of Science                                         1
# Network Pharmacology                                                               1
# International Journal of Ophthalmology and Clinical Research                       1
# Synthese                                                                           1
# Âncora: Revista Latino-Americana De Jornalismo                                     1
# Learning Environments Research                                                     1
# Asian Journal of Education and E-Learning                                          1
# Name: journal_name, Length: 11581, dtype: int64
#
#  UNIQUE VALUE TOTALS
#  pub_name
# 3529
# Springer                                                                   1886
# Hindawi Publishing Corporation                                              487
# Elsevier                                                                    294
# De Gruyter Open                                                             266
# BioInfo Publications                                                        142
# BioMed Central                                                              137
# Self Owned - Non-Profit Society                                             127
# American Scientific Publishers                                              119
# Biomed Central                                                              114
# Wiley                                                                       104
# AIRCC Publishing Corporation                                                101
# American Research Institute for Policy Development                           95
# Academic Journals                                                            93
# Canadian Center of Science and Education                                     86
# Medknow Publications                                                         81
# Austin Publishing Group                                                      77
# Dove Medical Press                                                           75
# Asian Network for Scientific Information (ansinet)                           65
# Biomed Central Ltd                                                           60
# Bentham Open                                                                 58
# American Association for Science and Technology (AASCIT)                     55
# Academicians Research Center (ARC)                                          54
# American V-King Scientific Publishing                                        52
# Libertas Academica                                                           51
# MDPI AG                                                                      51
# Donnish Journals                                                             50
# PAGEPress Publications                                                       46
# SAGE Publishing                                                              46
# Copernicus Publications                                                      44
# Frontiers Media S.A.                                                         43
#                                                                            ...
# Multimed Inc                                                                  1
# Universidade Estadual do Suodeste da Bahia                                    1
# José Domingo Villarroel                                                       1
# Sociedad Uruguaya de Pediatria                                                1
# Selva Andina Research Society                                                 1
# Associazione Culturale Engramma                                               1
#  Association of Naval Architects and Marine Engineers                         1
# Universität Heidelberg - Japanologie                                          1
# Grupo de Estudos Linguísticos do Estado de São Paulo                          1
# JackBran Consult Ltda.                                                        1
# Indiana University School of Social Work                                      1
# UMR Dridura                                                                   1
# Groupe détudes et de recherches pour le français langue internationale       1
# Editorial Universitaria UNAN León                                             1
# Bahauddin Zakariya University                                                 1
# DNT Ortadogu Yayincilik AS                                                    1
# South African Journal of Animal Sciences                                      1
# Slovak University of Agriculture in Nitra                                     1
# Centro Español de Documentación sobre Discapacidad (CEDD)                     1
# Czech Technical University in Prague                                          1
# UMP Publisher                                                                 1
# Associação dos Farmacêuticos do Vale do Aço                                   1
# Istanbul Commerce University                                                  1
# Assoc Computing Machinery                                                     1
# International Society for Comparative Psychology                              1
# Mordon Bt.                                                                    1
# University of Oslo & Uppsala University                                       1
# Red Iberoamericana de Investigación sobre Cambio y Eficacia Escolar           1
# Sekolah Tinggi Agama Islam Negeri (STAIN) Kudus                               1
# Universidad de La Rioja                                                       1
# Name: pub_name, Length: 3529, dtype: int64
#
#  UNIQUE VALUE TOTALS
#  is_hybrid
# 2
# 0    11414
# 1     1735
# Name: is_hybrid, dtype: int64
#
#  UNIQUE VALUE TOTALS
#  category
# 140
# Medicine                                           1647
# Science                                             890
# Technology                                          683
# Social Sciences                                     623
# Education                                           447
# Language and Literature                             427
# Geography. Anthropology. Recreation                 305
# Agriculture                                         291
# Philosophy. Psychology. Religion                    277
# Law                                                 152
# General Works                                       145
# Fine Arts                                           144
# History (General) and history of Europe             128
# Political science                                   119
# History America                                      41
# Auxiliary sciences of history                        39
# MOLECULAR AND CELL BIOLOGY                           36
# MEDICINE                                             35
# Physics and Chemistry                                20
# Music and books on Music                             19
# Molecular and Cell Biology                           18
# Medicine | Science                                   16
# PHYSICS AND CHEMISTRY                                15
# ECOLOGY AND EVOLUTION                                13
# Technology | Science                                 12
# Naval Science                                        11
# Neuroscience                                         11
# Ecology and Evolution                                10
# Political science | Social Sciences                   8
# NEUROSCIENCE                                          8
#                                                    ...
# Architecture                                          1
# Military Science | Political science                  1
# Literature                                            1
# Education | Philosophy. Psychology. Religion          1
# ORTHOPEDICS                                           1
# WOOD PRODUCTS                                         1
# OPHTHALMOLOGY                                         1
# DENTISTRY                                             1
# POLITICAL SCIENCE                                     1
# Education | Language and Literature                   1
# Radiology                                             1
# Arts and Humanities                                   1
# Education | Political science | Social Sciences       1
# SOCIOLOGY                                             1
# SPORTS MEDICINE                                       1
# PLASTIC SURGERY                                       1
# Informatics                                           1
# Dynamics                                              1
# Technology | Language and Literature                  1
# Technology | Medicine | Science                       1
# Philosophy. Psychology. Religion | Science            1
# Agriculture | Technology | Science                    1
# RHEUMATOLOGY                                          1
# Education | Geography. Anthropology. Recreation       1
# Marketing                                             1
# Language and Literature | Social Sciences             1
# Anthropology                                          1
# PSYCHOLOGY                                            1
# Circuits                                              1
# Technology | Philosophy. Psychology. Religion         1
# Name: category, Length: 140, dtype: int64
#
#  UNIQUE VALUE TOTALS
#  url
# 6327
# https://www.springer.com/us/open-access/springer-open-choice                       14
# https://www.hindawi.com/journals/acp/                                               3
# http://www.biodiversnathist.com                                                     2
# http://www.egms.de/dynamic/en/journals/zma/index.htm                                2
# https://www.hindawi.com/journals/jqre/                                              2
# http://www.ocl-journal.org/                                                         2
# http://www.kmuj.kmu.edu.pk/index                                                    2
# http://epress.lib.uts.edu.au/journals/index.php/AJCEB                               2
# http://www.scoliosisjournal.com/                                                    2
# https://www.hindawi.com/journals/jcnc/                                              2
# http://www.collabra.org                                                             2
# http://www.degruyter.com/view/j/plua                                                2
# http://www.lawcrimehistory.org/journal.htm                                          2
# http://newvoices.org.au/                                                            2
# http://www2.um.edu.uy/ingenieria/revista/                                           2
# https://www.hindawi.com/journals/jchem/                                             2
# http://www.springer.com/us/open-access/springer-open-choice                         2
# http://www.biogeosciences.net                                                       2
# http://www.ddtjournal.org/                                                          2
# http://gymnica.upol.cz                                                              2
# http://efsupit.ro/                                                                  2
# http://www.fupress.net/index.php/asf                                                1
# http://elgeniomaligno.eu/                                                           1
# http://journal.uinjkt.ac.id/index.php/signifikan                                    1
# http://www.revistabarataria.es                                                      1
# http://www.demetra.uerj.br                                                          1
# http://iisit.org/                                                                   1
# http://www.parasite-journal.org/                                                    1
# http://www.degruyter.com/view/j/scjme                                               1
# http://bes.cims.edu.pk/index.html                                                   1
#                                                                                    ..
# http://journal.science-res.com/index.php?journal=JCLAD                              1
# https://www.hindawi.com/journals/jmb/                                               1
# http://www.scopemed.org/?jid=20                                                     1
# http://www.fupress.net/index.php/ceset/index                                        1
# http://sljfmsl.sljol.info/                                                          1
# http://revistapos.cruzeirodosul.edu.br/index.php/rencima                            1
# http://www.pvj.com.pk                                                               1
# http://cristal.epubs.ac.za/index.php/cristal/index                                  1
# http://revistas.unisinos.br/index.php/versoereverso/index                           1
# http://www.journals.elsevier.com/regenerative-therapy/                              1
# https://pynchonnotes.openlibhums.org/                                               1
# http://revistes.uab.cat/periferia                                                   1
# https://jper.uib.no                                                                 1
# http://revistasaluduis.uis.edu.co/                                                  1
# https://www.hindawi.com/journals/ert/                                               1
# http://www.nucleus.feituverava.com.br/index.php/animalium                           1
# http://et.worldeconomicsassociation.org/index                                       1
# http://www.termedia.pl/Journal/Archives_of_Forensic_Medicine_and_Criminology-82     1
# http://www.educade.es                                                               1
# http://eb.bio.uni-plovdiv.bg/                                                       1
# http://ojs.tdmu.edu.ua/index.php/ijmr/index                                         1
# http://www.pesd.ro                                                                  1
# https://jurnal.uns.ac.id/index.php?journal=alchemy&page=index                       1
# http://sserr.ro                                                                     1
# http://www.centmapress.org                                                          1
# http://dergipark.ulakbim.gov.tr/cbayarfbe                                           1
# http://periodicos.pucminas.br/index.php/geografia/index                             1
# http://www.ojoonline.org/                                                           1
# http://www.vrrjournal.org.br/index.php/vrrjournal                                   1
# http://onlinelibrary.wiley.com/journal/10.1007/13539.2190-6009                      1
# Name: url, Length: 6327, dtype: int64

# %% [markdown]
# ## 1.b: Deduplication

# %% [markdown]
# ### ID / Unique Identifier
# It's especially important to make sure that it's... **unique**!... So use duplicated() as above.

# %%
# Lets check if we have any serial number duplication

print(df['issn'].duplicated())    
# this takes the column 'issn' from df
# returns a True or False if it's a duplicated value
# returns True when it reaches the second value, by default.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 13119    False
# 13120    False
# 13121    False
# 13122    False
# 13123    False
# 13124    False
# 13125    False
# 13126    False
# 13127    False
# 13128    False
# 13129    False
# 13130    False
# 13131    False
# 13132    False
# 13133    False
# 13134    False
# 13135    False
# 13136    False
# 13137    False
# 13138    False
# 13139    False
# 13140    False
# 13141    False
# 13142    False
# 13143    False
# 13144    False
# 13145    False
# 13146    False
# 13147    False
# 13148    False
# Name: issn, Length: 13149, dtype: bool

# %%
print(any(df['issn'].duplicated())) 
# any is a method that iterates through strings and returns a boolean value based on the condition. 
# returning false means that no duplicate values were found in issn
# Out:
# False

# %% [markdown]
# #### There are no duplicate values in the 'issn' column (output was False)

# %%
print(any(df['journal_name'].duplicated())) 
# any is a method that iterates through strings and returns a boolean value based on the condition. 
# returning false means that no duplicate values were found in issn
# Out:
# True

# %% [markdown]
# #### There *are* duplicate values under 'journal_name' column (output was True)

# %%
print(any(df['pub_name'].duplicated()))
# Out:
# True

# %% [markdown]
# #### There are also duplicate values under 'pub_name' column (output was True)

# %%
#We can also check for duplication in multiple columns using the same logic

print(any(df.duplicated(['journal_name', 'pub_name','url'])))
# Out:
# True

# %%
#We can also check for duplication in multiple columns using the same logic

df.duplicated(['journal_name', 'pub_name','url'], keep='first')
# we think it means all three of those need to be duplicated... the whole row across...
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 13119     True
# 13120    False
# 13121    False
# 13122    False
# 13123     True
# 13124     True
# 13125    False
# 13126     True
# 13127    False
# 13128     True
# 13129     True
# 13130    False
# 13131     True
# 13132     True
# 13133     True
# 13134    False
# 13135    False
# 13136     True
# 13137    False
# 13138     True
# 13139     True
# 13140     True
# 13141     True
# 13142    False
# 13143     True
# 13144     True
# 13145     True
# 13146    False
# 13147     True
# 13148     True
# Length: 13149, dtype: bool

# %%
# above block of code shows which are true or false.

#Lets *see* the dupes

df[df.duplicated(['journal_name', 'pub_name','url'], keep='first')] 
# specifying keep=first counts the first occurring value as original and the remaining as duplicates
# this prints out the ones that are True! ah! ;) Nice. I get it now.
# this block of code actually prints them out for us to see!
# Out:
#             issn                                       journal_name  \
# 132    0053-0016  International Journal of Recent Surgical and M...
# 133    0053-0017  International Journal of Recent Surgical and M...
# 134    0053-0018  International Journal of Recent Surgical and M...
# 135    0053-0019  International Journal of Recent Surgical and M...
# 136    0053-0020  International Journal of Recent Surgical and M...
# 137    0053-0021  International Journal of Recent Surgical and M...
# 138    0053-0022  International Journal of Recent Surgical and M...
# 139    0053-0023  International Journal of Recent Surgical and M...
# 140    0053-0024  International Journal of Recent Surgical and M...
# 141    0053-0025  International Journal of Recent Surgical and M...
# 142    0053-0026  International Journal of Recent Surgical and M...
# 435    0719-4986                   Biodiversity and Natural History
# 454    0812-1126         Biointerface Research in Applied Chemistry
# 455    0812-1135         Biointerface Research in Applied Chemistry
# 456    0812-1137         Biointerface Research in Applied Chemistry
# 533    0973-7294   International Journal of Tomography & Simulation
# 534    0973-7308     International Journal of Ecology & Development
# 535    0973-7537  International Journal of Ecological Economics ...
# 536    0973-7545  International Journal of Applied Mathematics a...
# 548    0974-0910                Journal of Cell and Tissue Research
# 562    0974-5718  International Journal of Mathematics & Computa...
# 578    0974-8998                   Journal of Networking Technology
# 596    0975-2293  International Journal of Computer Networks & C...
# 597    0975-2307  International Journal of Network Security & It...
# 616    0975-427X                         Asian Journal of Chemistry
# 618    0975-4660  International Journal of Computer Science & In...
# 619    0975-4679  International Journal of Wireless & Mobile Net...
# 627    0975-5926  International Journal of Managing Information ...
# 628    0975-5934  The International Journal of Multimedia & Its ...
# 629    0975-5985  International Journal of Database Management S...
# ...          ...                                                ...
# 13107  6095-2015  International Journal of Application or Innova...
# 13109  6633-2016  International Journal of Engineering Trends an...
# 13110  6755-4183  International Journal of Recent Scientific Res...
# 13111  6776-9071     International Journal of Computer Applications
# 13112  7105-2016  International Journal of Engineering Research ...
# 13113  7195-9290               Advances in Biomedicine and Pharmacy
# 13114  7256-3713    International Journal of Research GRANTHAALAYAH
# 13115  7258-7266                    Genetics and Molecular Research
# 13116  7356-2016  International Journal of Recent Scientific Res...
# 13117  7494-2016  International Journal of Engineering and Appli...
# 13118  7582-2014  International Journal for Research in Emerging...
# 13119  7801-2016  International Journal of Engineering Sciences ...
# 13123  7901-2015      International Journal of Development Research
# 13124  7937-2015  International Journal of Advance Research and ...
# 13126  8140-2016  International Journal of Innovative and Applie...
# 13128  8244-8750  International Journal of Computer Engineering ...
# 13129  8247-2016  International Journal of Emerging Research in ...
# 13131  8455-2015         International Journal of Indian Psychology
# 13132  8487-6366  Canadian International Journal of Science and ...
# 13133  8555-2016  American Journal of Innovative Research and Ap...
# 13136  9001-2008  International Journal of Engineering Technolog...
# 13138  9134-2016  International Journal of Computer Engineering ...
# 13139  9138-2015  International Journal of Engineering Sciences ...
# 13140  9341-2016  International Journal of New Technology and Re...
# 13141  9377-2016  International Journal of Current Advanced Rese...
# 13143  9521-5978  International Journal of Dental and Health Sci...
# 13144  9680-5667  International Journal of Innovative Computer S...
# 13145  9681-2016  International Journal for Research in Applied ...
# 13147  9826-4263               Advances in Biomedicine and Pharmacy
# 13148  9933-2016  International Journal for Development of Compu...
#
#                                              pub_name  is_hybrid category  \
# 132                                               NaN          0      NaN
# 133                                               NaN          0      NaN
# 134                                               NaN          0      NaN
# 135                                               NaN          0      NaN
# 136                                               NaN          0      NaN
# 137                                               NaN          0      NaN
# 138                                               NaN          0      NaN
# 139                                               NaN          0      NaN
# 140                                               NaN          0      NaN
# 141                                               NaN          0      NaN
# 142                                               NaN          0      NaN
# 435               Centro de Estudios en Biodiversidad          0  Science
# 454                                               NaN          0      NaN
# 455                                               NaN          0      NaN
# 456                                               NaN          0      NaN
# 533                                CESER Publications          0      NaN
# 534                                CESER Publications          0      NaN
# 535                                CESER Publications          0      NaN
# 536                                CESER Publications          0      NaN
# 548                                  CTR Publications          0      NaN
# 562                                CESER Publications          0      NaN
# 578    Digital Information Research Foundation (DIRF)          0      NaN
# 596                      AIRCC Publishing Corporation          0      NaN
# 597                      AIRCC Publishing Corporation          0      NaN
# 616                                               NaN          0      NaN
# 618                      AIRCC Publishing Corporation          0      NaN
# 619                      AIRCC Publishing Corporation          0      NaN
# 627                      AIRCC Publishing Corporation          0      NaN
# 628                      AIRCC Publishing Corporation          0      NaN
# 629                      AIRCC Publishing Corporation          0      NaN
# ...                                               ...        ...      ...
# 13107                                             NaN          0      NaN
# 13109                                             NaN          0      NaN
# 13110                                             NaN          0      NaN
# 13111                                             NaN          0      NaN
# 13112                                             NaN          0      NaN
# 13113                                             NaN          0      NaN
# 13114                                             NaN          0      NaN
# 13115                                             NaN          0      NaN
# 13116                                             NaN          0      NaN
# 13117                                             NaN          0      NaN
# 13118                                             NaN          0      NaN
# 13119                                             NaN          0      NaN
# 13123                                             NaN          0      NaN
# 13124                                             NaN          0      NaN
# 13126                                             NaN          0      NaN
# 13128                                             NaN          0      NaN
# 13129                                             NaN          0      NaN
# 13131                                             NaN          0      NaN
# 13132                                             NaN          0      NaN
# 13133                                             NaN          0      NaN
# 13136                                             NaN          0      NaN
# 13138                                             NaN          0      NaN
# 13139                                             NaN          0      NaN
# 13140                                             NaN          0      NaN
# 13141                                             NaN          0      NaN
# 13143                                             NaN          0      NaN
# 13144                                             NaN          0      NaN
# 13145                                             NaN          0      NaN
# 13147                                             NaN          0      NaN
# 13148                                             NaN          0      NaN
#
#                                    url
# 132                                NaN
# 133                                NaN
# 134                                NaN
# 135                                NaN
# 136                                NaN
# 137                                NaN
# 138                                NaN
# 139                                NaN
# 140                                NaN
# 141                                NaN
# 142                                NaN
# 435    http://www.biodiversnathist.com
# 454                                NaN
# 455                                NaN
# 456                                NaN
# 533                                NaN
# 534                                NaN
# 535                                NaN
# 536                                NaN
# 548                                NaN
# 562                                NaN
# 578                                NaN
# 596                                NaN
# 597                                NaN
# 616                                NaN
# 618                                NaN
# 619                                NaN
# 627                                NaN
# 628                                NaN
# 629                                NaN
# ...                                ...
# 13107                              NaN
# 13109                              NaN
# 13110                              NaN
# 13111                              NaN
# 13112                              NaN
# 13113                              NaN
# 13114                              NaN
# 13115                              NaN
# 13116                              NaN
# 13117                              NaN
# 13118                              NaN
# 13119                              NaN
# 13123                              NaN
# 13124                              NaN
# 13126                              NaN
# 13128                              NaN
# 13129                              NaN
# 13131                              NaN
# 13132                              NaN
# 13133                              NaN
# 13136                              NaN
# 13138                              NaN
# 13139                              NaN
# 13140                              NaN
# 13141                              NaN
# 13143                              NaN
# 13144                              NaN
# 13145                              NaN
# 13147                              NaN
# 13148                              NaN
#
# [1133 rows x 6 columns]

# %% [markdown]
# ### the rest of this section, we skipped.

# %%
#We don't want to do anything about the nulls just yet. However, they are being counted towards our duplicate values.
#To work around this, we can do a groupby and size on our duplicated columns and add an occurrence count column.


#Let's make it a new dataframe for better access
jour_pub_url_group = df.groupby(['journal_name','pub_name','url']).size().reset_index().\
                    rename(columns={0:'occurrence_count'})

# %%
# Lets see how many values are duplicated across journal_name,pub_name and url


jour_pub_url_group[jour_pub_url_group['occurrence_count']>1]

# %%
#Now let's see how many values are duplicated in the entire dataset

dupe_check_all_df= df.groupby(df.columns.tolist()).size().reset_index().\
                       rename(columns={0:'occurrence_count'})

# %%
# To get the total number of dupes, we can subtract the shape of our data from the occurence count total

dupe_check_all_df['occurrence_count'].sum() - dupe_check_all_df.shape[0]

# %% [markdown]
# There is a duplicate value in the journal_name, pub_name, and url columns. However, I am in no way  a subject matter expert in academic journals, so  I don't want to assume that this means that the data is inherently wrong.
# Since the issn column can be considered a unique identifier and does not contain duplicates, I believe the right move is to continue working with the data as is and consult the owners of the dataset later for clarification.

# %% [markdown]
# ## 1.c:  Standardization and String Matching

# %% [markdown]
# ### this is where we picked back up!

# %%
# From what we've already seen of the data, we can recognize that character case is 
# inconsistent in pub_name and category columns
# This can be quickly fixed by converting all columns with object datatypes to lowercase

df = df.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)

df.head(2)
# Out:
#         issn              journal_name                  pub_name  is_hybrid  \
# 0  0001-527x  acta biochimica polonica  acta biochimica polonica          0
# 1  0002-0397           africa spectrum                       NaN          0
#
#                      category  url
# 0  molecular and cell biology  NaN
# 1                         NaN  NaN

# %%
#We can alse apply the same string functions to individual columns...


df['journal_name'] = df['journal_name'].str.title() 
# Let's make journal_name title case
# Careful with this one,it doesn't discriminate and will capitalize articles and prepositions

df['issn']= df['issn'].str.upper() #And lets make issn uppercase 

df.head()
# Out:
#         issn                                       journal_name  \
# 0  0001-527X                           Acta Biochimica Polonica
# 1  0002-0397                                    Africa Spectrum
# 2  0003-0090  Bulletin Of The American Museum Of Natural His...
# 3  0003-5521                                    L'Anthropologie
# 4  0004-1254  Arhiv Za Higijenu Rada I Toksikologiju-Archive...
#
#                       pub_name  is_hybrid                    category  url
# 0     acta biochimica polonica          0  molecular and cell biology  NaN
# 1                          NaN          0                         NaN  NaN
# 2  amer museum natural history          0       ecology and evolution  NaN
# 3                     elsevier          1                anthropology  NaN
# 4                          NaN          0                         NaN  NaN

# %% [markdown]
# ### we also skipped the few cells above, here.

# %% [markdown]
# ### we began again with the cell below.

# %%
 df['category'].unique()

# Looking at the unique values of the category column we can see that 
# we still have some problems with inconsistent delimiter use

# We want to standardize the data and make it more consistent
# Out:
# array(['molecular and cell biology', nan, 'ecology and evolution',
#        'anthropology', 'robotics', 'physics and chemistry', 'psychology',
#        'medicine', 'neuroscience', 'veterinary', 'economics', 'law',
#        'gastroenterology', 'plant biology', 'orthopedics', 'agriculture',
#        'linguistics', 'history and philosophy of science', 'mathematics',
#        'oncology', 'sports medicine', 'food science', 'psychiatry',
#        'science', 'radiology', 'urology', 'environmental health',
#        'social sciences', 'ophthalmology', 'marketing',
#        'astronomy and astrophysics', 'operations research',
#        'infectious diseases', 'literary studies', 'plastic surgery',
#        'energy', 'structural engineering',
#        'philosophy. psychology. religion', 'fine arts',
#        'music and books on music', 'history america',
#        'geography. anthropology. recreation', 'political science',
#        'language and literature', 'technology', 'education',
#        'general works', 'history (general) and history of europe',
#        'technology | law', 'history america | social sciences',
#        'auxiliary sciences of history',
#        'political science | social sciences', 'computer science',
#        'information & library sciences',
#        'library and information science', 'education | technology',
#        'medicine | science', 'circuits', 'information science',
#        'geotechnology', 'sociology', 'nephrology', 'dentistry',
#        'rheumatology', 'pharmacology', 'agriculture | science',
#        'medicine | social sciences',
#        'fine arts | geography. anthropology. recreation', 'informatics',
#        'communication & media studies', 'education | science',
#        'military science', 'technology | social sciences',
#        'law | social sciences', 'naval science', 'technology | science',
#        'agriculture | technology', 'law | political science',
#        'languages & linguistics',
#        'geography. anthropology. recreation | science',
#        'philosophy. psychology. religion | social sciences',
#        'wood products', 'fine arts | language and literature',
#        'technology | language and literature', 'fine arts | science',
#        'literature', 'policy and law',
#        'education | political science | social sciences',
#        'agriculture | medicine', 'business & management',
#        'medicine | philosophy. psychology. religion',
#        'education | social sciences',
#        'education | language and literature', 'law | medicine',
#        'general science & technology', 'nursing',
#        'language and literature | social sciences',
#        'agriculture | geography. anthropology. recreation',
#        'scholarly publishing', 'agriculture | technology | science',
#        'technology | medicine', 'technology | medicine | science',
#        'philosophy. psychology. religion | science',
#        'education | philosophy. psychology. religion',
#        'technology | philosophy. psychology. religion',
#        'education | medicine', 'scientific equipment', 'dynamics',
#        'education | geography. anthropology. recreation',
#        'arts & humanities', 'architecture',
#        'military science | political science', 'arts and humanities'],
#       dtype=object)

# %%
# Lets replace 'and' with '&'
df['category'].replace(to_replace='and', value='&', regex=True, inplace=True)

# %% [markdown]
# #### cell above:
# regex=True means you are using regex to match.
#
# inplace=True means you would like to overwrite the column with the result of the action.
#
# it basically does this:
# - df['category'] = df['category'].replace(to_replace='and', value='&', regex=True, inplace=True)
#
# if you DO NOT DO inplace=True, it basically just prints out what happens, but doesn't SAVE the change.

# %%
# Now back to those pesky delimiters ...

# Overall, there are 12 metacharacters you should look out for  . ^ $ * + ? { } [ ] \ | ( )
# Both the pipe(|) and period(.) are considered metacharacters because they have special meaning.
 
# Regular expressions use the backslash character ('\') to indicate special forms or to allow special characters to be used without invoking their meaning. 

# This conflicts with Python’s usage of the same character for the same purpose in string literals and can become a pain when backslash
# proliferation makes things unreadable

print('ESCAPING WITH BACKSLASHES\n')
print('ROW CONTAINS PIPE \n', df['category'].str.contains('\\|').sum())
print('ROW CONTAINS PERIOD \n', df['category'].str.contains('\\.').sum())
print('ROW CONTAINS BACKSLASH \n', df['category'].str.contains('\\\\').sum()) #This is when the backslashes really scale up
print('ROW CONTAINS OPEN PARENTHESIS \n', df['category'].str.contains('\\(').sum())
print('ROW CONTAINS CLOSE PARENTHESIS \n', df['category'].str.contains('\\)').sum())

# %%
# A cleaner solution for this is to use raw string notation in addition to a backslash by adding an r outside of the quoted expression.
print('ESCAPING WITH RAW STRING NOTATION \n')
print('ROW CONTAINS PIPE \n', df['category'].str.contains(r'\|').sum())
print('ROW CONTAINS PERIOD \n', df['category'].str.contains(r'\.').sum())
print('ROW CONTAINS BACKSLASH \n', df['category'].str.contains(r'\\').sum())
print('ROW CONTAINS OPEN PARENTHESIS \n', df['category'].str.contains(r'\(').sum())
print('ROW CONTAINS CLOSE PARENTHESIS \n', df['category'].str.contains(r'\)').sum())

# %%
#Intuitively, we can see that parenthesis are being used differently than pipes in the context of this dataset. 
#Because of this, we will leave them out of the special chars replacement.


special_chars=r'\.|\^|\$|\*|\+|\?|\{|\}|\[|\]|\\|\|' # Note that with the backslash, we're searching for the literal | character 
                                                     # Without the backslash we're using | as an OR statement

  
len(df[df['category'].str.contains(special_chars,na=False,regex=True)])

# %%
#Lets replace the special characters with an underscore.

df['category'].replace(to_replace=special_chars, value='_', regex=True, inplace=True)

# %%
df.category

# %%
#Now lets clean up the whitespace before and after the underscore

df['category']=df['category'].replace('_ ', '_',regex=True).replace(' _','_',regex=True)

# %%
df['category'].unique()

# %% [markdown]
# # Part 2: Handling Missing Data

# %% [markdown]
# ## 2.1 On Missingness
#
# Resource: http://www.stat.columbia.edu/~gelman/arm/missing.pdf
#
#
# 1. **Missingness completely at random (MCAR)**. A variable is missing completely at random if the probability of missingness is the same for all units, for example, if each survey respondent decides whether to answer the “earnings” question by rolling a die and refusing to answer if a “6” shows up. If data are missing completely at
# random, then throwing out cases with missing data does not bias your inferences.
#
# 2. **Missingness at random (MAR)**. Missing at random means that the propensity for a data point to be missing is not related to the missing data, but it is related to some of the observed data.
# Most missingness is not completely at random, as can be seen from the data themselves. A more general assumption, missing at random, is that the probability a variable
# is missing depends only on available information. Thus, if sex, race, education, and age are recorded for all the people in the survey, then “earnings” is missing at random if the probability of nonresponse to this question depends only on these other, fully recorded variables. It is often reasonable to model this process as a logistic regression, where the outcome variable equals 1 for observed cases
# and 0 for missing. When an outcome variable is missing at random, it is acceptable to exclude the missing cases (that is, to treat them as NA’s), as long as the regression controls for all the variables that affect the probability of missingness. Thus, any model
# for earnings would have to include predictors for ethnicity, to avoid nonresponse bias. This missing-at-random assumption (a more formal version of which is sometimes called the ignorability assumption) in the missing-data framework is the basically same sort of assumption as ignorability in the causal framework. Both require that sufficient information has been collected that we can “ignore” the
# assignment mechanism (assignment to treatment, assignment to nonresponse).
# 3. **Missingness not at random (MNAR)**:
# . Missingness is no longer “at random” if it depends on information that has not been recorded and this information also predicts the missing values. For example, suppose that “surly”
# people are less likely to respond to the earnings question, surliness is predictive
# of earnings, and “surliness” is unobserved. Or, suppose that people with college
# degrees are less likely to reveal their earnings, having a college degree is predictive of earnings, and there is also some nonresponse to the education question.
# Then, once again, earnings are not missing at random. If missingness is not at random, it must be explicitly modeled, or else you must
# accept some bias in your inferences. There are two types:
#
# *   **Missingness that depends on unobserved predictors**. A familiar example from medical studies is that if a particular treatment causes
# discomfort, a patient is more likely to drop out of the study. This missingness is
# not at random (unless “discomfort” is measured and observed for all patients).
# *   **Missingness that depends on the missing value itself**. Finally, a particularly difficult situation arises when the probability of missingness depends on the (potentially missing) variable itself. For example, suppose that people with higher earnings are less likely to reveal them. In the extreme case (for example, all persons earning more than $100,000 refuse to respond), this is called censoring, but
# even the probabilistic case causes difficulty.
#
# In the first two cases, it is safe to remove the data with missing values depending upon their occurrences.
#
# In the third case (MNAR), removing observations with missing values can produce a bias in the model.
#
# So we have to be really careful before removing observations.

# %% [markdown]
# ## 2.2 Choices, Choices
#
# There are 3 choices for missing data:
#
# **1.   Imputation: Fill in the missing data**
# *   User provided data
# *   Summary statistic (Be careful here: mean, median, mode, etc. Use median if you have outliers)
# *   Modeled or imputed data
# *   Data present in dataset
#
# **2. Deletion: Drop rows or columns with missing data**
# *   Drop all
# *   Drop some, based on conditions or a threshold
#
# **3. Leave it as is**
#
# **When should one fill in data, drop data, or leave it alone? **
#
# It depends. . . .

# %% [markdown]
# ![Handling Missing Data](https://cdn-images-1.medium.com/max/1600/1*_RA3mCS30Pr0vUxbp25Yxw.png)

# %% [markdown]
# ##  2.3 Let's Get to Work
#
# ### 2.3.1 Data Quality Check
# Let's check out our data

# %%
#Check out the dataset
df.head()

# %% [markdown]
# ## 2.4 Assessing Missingness
#
# How much missingness is there?

# %%
#Check out the column types
df.dtypes

# %%
# Let's find out which columns have missing data
missing_columns = list(df.columns[df.isnull().any()])
missing_columns

# %%
#Let's find out how many missing values are in each column

for col in missing_columns:
    num_missing = df[df[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, 
                                                    num_missing))

# %%
#Percentage of missingness per column
for col in missing_columns:
    percent_missing = df[df[col].isnull() == True].shape[0]  / df.shape[0] * 100
    print('percent missing for column {}: {}%'.format(
        col, percent_missing))

# %% [markdown]
# ## 2.5 DELETION
# If you have a "small" amount of data missing:
#
#
# 1.   **Listwise deletion**: remove ALL data for an observation that has at least 1 missing value.
# > *Problem: Meeting MCAR assumptions are rare; as a result most of time you'll produce biased parameters and estimates*
#
#
# 2.   **Pairwise deletion**: Keep all data that isn't missing. Even though it increases the power of your analysis, you'll end up with different numbers of observations contributing to different parts of your model. This makes interpretation very difficult.
#
# 2.   **Deleting Columns**: Keep all data that isn't missing. Even though it increases the power of your analysis, you'll end up with different numbers of observations contributing to different parts of your model. This makes interpretation very difficult.
#
#
#
# ### 2.5.1 Remove Null Values Upon Reading in Data

# %%
#Call na_values to remove n/a values
# Making a list of missing value types
# Read in data using Pandas and quickly ELIMINATE missing values based on list of missing value types
missing_values = ["n/a", "na", "--"]
df = pd.read_csv(url, na_values = missing_values)
df.head(10)

# %%
df.shape

# %% [markdown]
# ## 2.6 What to do with NaNs?

# %% [markdown]
# If you need to fill in errors or blanks, use the ```fillna()``` and ```dropna()``` methods.
#
# It seems quick, but all manipulations of the data should be documented so you can explain them to someone at a later time.
#
# You could fill the NaNs with strings, or if they are numbers you could use the mean or the median value. There is a lot of debate on what do with missing or malformed data, and the correct answer is … it depends.
#
# You’ll have to use your best judgement and input from the people you’re working with on why removing or filling the data is the best approach.

# %%
#Now we see that 6788 values are filled in with 0
df.url.value_counts()

# %% [markdown]
# ### 2.6.1 Filling in Data

# %%
# First, find the value counts of the URL column
df.url.value_counts()

# %%
# The top missing values in the URL column
df.url.value_counts().head()

# %%
# Fill in missing data using the .fillna method
# Let's fill in missing values with 0
df.url = df.url.fillna(0)

# Fill NaN with ' '
#df['url'] = df['url'].fillna(' ')

# Fill NaN with 999
#df['url'] = df['url'].fillna(999)

# Fill NaN with the mean of the column -- for numeric columns only!!
#df['url'] = df['url'].fillna(df['url'].mean())

# %% [markdown]
# You can also propagate non-null values forward or backwards by using ```method=’pad’``` as the method argument.
#
#
# It will fill the next value in the dataframe with the previous non-NaN value.
#
# When you want to fill one value, use ```limit=1```.
#
# If you don't set a limit, you'll fill in the entire dataframe
#
# Let's create a dataframe to demo forward fill and backfilll:

# %%
missing_df = pd.DataFrame(data={'col1':[np.nan, np.nan, 23,3,14,5,13, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]})
missing_df

# %%
missing_df.fillna(method='pad', limit=1)
# See that index 7 is filled in with index 6's value

# %%
# If you don't set a limit, you'll fill in the rest of the entire dataframe 
missing_df.fillna(method='pad')

# %% [markdown]
# ### 2.6.2 Backfilling
#
# We are not limited to forward filling. We can  also backfill with bfill.

# %%
#The first two values are NaN's. Let's backfill them
missing_df

# %%
# Fill the first two NaN values with the first available value
missing_df.fillna(method='bfill')

# %% [markdown]
# ## 2.7 Dropping Missing Data
#
# Use the ```dropna``` method to drop rows or columns with NaNs.

# %%
# Drop any rows which have any nans
missing_df.dropna()

# %%
# Drop columns that have any nans
missing_df.dropna(axis=1)

# %% [markdown]
# ### 2.7.1 NaNs thresholding
# The parameter thresh=N requires that a column has at least N non-NaNs to survive. Think of this as the lower limit for missing data you will find acceptable in your columns.

# %%
#Use a threshold to drop NaNs
# Only drop columns which have at least 20% non-NaNs
missing_df.dropna(thresh=int(missing_df.shape[0] * .20), axis=1)

# %% [markdown]
# ## 2.8 IMPUTATION
#
# ### 2.8.1 SIMPLE IMPUTATION

# %% [markdown]
# Replace missing values, encoded as ```np.nan```, using the mean value of the columns (axis 0) that contain the missing values.
#
# Missing values can be imputed with a provided constant value, or using the statistics (mean, median or most frequent) of each column in which the missing values are located.
#
# #### 2.8.1.1 For Numeric NaNs

# %%
#NUMERIC NaNs
#Impute with the mean
#This will look for all columns where we have NaN value and replace the NaN value with specified test statistic.

from sklearn.impute import SimpleImputer
imputed_data = SimpleImputer(missing_values=np.nan, strategy='mean')
#Change strategy to 'median', and for the mode: 'most_frequent' 

imputed_data.fit(missing_df) #use .fit

missing_df = pd.DataFrame(imputed_data.transform(missing_df)) #use.transform
missing_df

# %%
#Let's look at the parameters of the SimpleImputer
imputed_data

# %% [markdown]
# #### 2.8.1.2 For Categorical or *String* Data
#
# The SimpleImputer class also supports categorical data represented as string values or pandas categoricals when using the 'most_frequent' or 'constant' strategy.

# %%
#Let's create a dataframe with categorical or string data
categorical_df = pd.DataFrame([["a", "x"],
                               [np.nan, "y"],
                               ["a", np.nan],
                               ["b", "y"]], dtype="category")

#Let's take a look at this new dataframe
categorical_df

#the most frequent value in each column is 'a' and the 'y'

# %%
#Replacing the NaNs with the most frequent observation
cat_imp = SimpleImputer(strategy="most_frequent")
print(cat_imp.fit_transform(categorical_df))

# %%
cat_imp

# %% [markdown]
# ## 2.9 Now Let's Get Fancy: FancyImpute

# %% [markdown]
# #### 2.9.1 Imputation Algorithms
#
# **SimpleFill**: Replaces missing entries with the mean or median of each column.
#
# **KNN**: Nearest neighbor imputations which weights samples using the mean squared difference on features for which two rows both have observed data.
#
# **IterativeImputer**: A strategy for imputing missing values by modeling each feature with missing values as a function of other features in a round-robin fashion.
#
# **SoftImpute**: Matrix completion by iterative soft thresholding of SVD decompositions. Inspired by the softImpute package for R, which is based on Spectral Regularization Algorithms for Learning Large Incomplete Matrices by Mazumder et. al.
#
#
# **MatrixFactorization**: Direct factorization of the incomplete matrix into low-rank U and V, with an L1 sparsity penalty on the elements of U and an L2 penalty on the elements of V. Solved by gradient descent.
#
# **NuclearNormMinimization**: Simple implementation of Exact Matrix Completion via Convex Optimization by Emmanuel Candes and Benjamin Recht using cvxpy. Too slow for large matrices.
#
# **BiScaler**: Iterative estimation of row/column means and standard deviations to get doubly normalized matrix. Not guaranteed to converge but works well in practice. Taken from Matrix Completion and Low-Rank SVD via Fast Alternating Least Squares.

# %% [markdown]
# ### Implementing Multiple Imputation
# We are using the metric -- Mean Square Error.
#
# Let's run all the imputation algorithms to see which one gives us the lowest error. The goal is to have an MSE of zero.

# %%
#Let's run all the imputation algorithms and see which ones give us the lowest error

import numpy as np
from fancyimpute import (
    BiScaler,
    KNN,
    IterativeImputer,
    NuclearNormMinimization,
    SoftImpute,
    SimpleFill)

n = 200
m = 20
inner_rank = 4
X = np.dot(np.random.randn(n, inner_rank), np.random.randn(inner_rank, m))
print("Mean squared element: %0.4f" % (X ** 2).mean())

# X is a data matrix which we're going to randomly drop entries from
missing_mask = np.random.rand(*X.shape) < 0.1
X_incomplete = X.copy()
# missing entries indicated with NaN
X_incomplete[missing_mask] = np.nan

meanFill = SimpleFill("mean")
X_filled_mean = meanFill.fit_transform(X_incomplete)

# Model each feature with missing values as a function of other features, and
# use that estimate for imputation.
X_filled_ii = IterativeImputer().fit_transform(X_incomplete)

# Use 3 nearest rows which have a feature to fill in each row's missing features
knnImpute = KNN(k=3)
X_filled_knn = knnImpute.fit_transform(X_incomplete)

# matrix completion using convex optimization to find low-rank solution
# that still matches observed values. Slow!
X_filled_nnm = NuclearNormMinimization().fit_transform(X_incomplete)

# Instead of solving the nuclear norm objective directly, instead
# induce sparsity using singular value thresholding
softImpute = SoftImpute()

# simultaneously normalizes the rows and columns of your observed data,
# sometimes useful for low-rank imputation methods
biscaler = BiScaler()

# rescale both rows and columns to have zero mean and unit variance
X_incomplete_normalized = biscaler.fit_transform(X_incomplete)

X_filled_softimpute_normalized = softImpute.fit_transform(X_incomplete_normalized)
X_filled_softimpute = biscaler.inverse_transform(X_filled_softimpute_normalized)

X_filled_softimpute_no_biscale = softImpute.fit_transform(X_incomplete)

meanfill_mse = ((X_filled_mean[missing_mask] - X[missing_mask]) ** 2).mean()
print("meanFill MSE: %f" % meanfill_mse)

# print mean squared error for the four imputation methods above
# print mean squared error for the three imputation methods above
ii_mse = ((X_filled_ii[missing_mask] - X[missing_mask]) ** 2).mean()
print("Iterative Imputer norm minimization MSE: %f" % ii_mse)

nnm_mse = ((X_filled_nnm[missing_mask] - X[missing_mask]) ** 2).mean()
print("Nuclear norm minimization MSE: %f" % nnm_mse)

softImpute_mse = ((X_filled_softimpute[missing_mask] - X[missing_mask]) ** 2).mean()
print("SoftImpute MSE: %f" % softImpute_mse)

softImpute_no_biscale_mse = (
    (X_filled_softimpute_no_biscale[missing_mask] - X[missing_mask]) ** 2).mean()
print("SoftImpute without BiScale MSE: %f" % softImpute_no_biscale_mse)


knn_mse = ((X_filled_knn[missing_mask] - X[missing_mask]) ** 2).mean()
print("knnImpute MSE: %f" % knn_mse)

# %% [markdown]
# ### RESULTS
# We see that the Iterative Imputer and the Nuclear norm minimuxation has an MSE of 0.
#
# We see that simply filling missing values with the mean (meanFill) results in exponentially larger error.
#
# For the love of all that is good in the world, use iterative imputation over simple methods (where appropriate)
